# %%
import requests
from matplotlib import pyplot as plt
import numpy as np
from modelr.modelrAPI import modelrAPI, Rock, Fluid, ImageModel

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-291455f6d4e8> in <module>()
#       2 from matplotlib import pyplot as plt
#       3 import numpy as np
# ----> 4 from modelr.modelrAPI import modelrAPI, Rock, Fluid, ImageModel
#       5
#       6 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named modelrAPI

# %%
rocks = Rock.ls()
print rocks
# Out:
# [{u'key': u'ag9kZXZ-YWdpbGVtb2RlbHJyOwsSDE1vZGVsclBhcmVudBiAgICAgICACgwLEgRVc2VyGICAgICAgMAIDAsSBFJvY2sYgICAgICA2AkM', u'description': u'description\r\n\t\t  ', u'name': u'test2', u'fluid': None}, {u'key': u'ag9kZXZ-YWdpbGVtb2RlbHJyOwsSDE1vZGVsclBhcmVudBiAgICAgICACgwLEgRVc2VyGICAgICAgMAIDAsSBFJvY2sYgICAgICAmAsM', u'description': u'description\r\n\t\t  ', u'name': u'test', u'fluid': None}]

# %%
rock = Rock.get(rocks[0]["key"])
dir(rock)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'auth',
#  'fluid',
#  'from_json',
#  'get',
#  'handler',
#  'host',
#  'kclay',
#  'kqtz',
#  'ls',
#  'phi',
#  'porosity',
#  'rho',
#  'rho_std',
#  'url',
#  'vclay',
#  'vp',
#  'vp_std',
#  'vs',
#  'vs_std']

# %%
fluids = Fluid.ls()
print fluids
# Out:
# [{u'description': u'description', u'key': u'ag9kZXZ-YWdpbGVtb2RlbHJyPAsSDE1vZGVsclBhcmVudBiAgICAgICACgwLEgRVc2VyGICAgICAgMAIDAsSBUZsdWlkGICAgICAgKQIDA', u'name': u'fluid1'}, {u'description': u'description', u'key': u'ag9kZXZ-YWdpbGVtb2RlbHJyPAsSDE1vZGVsclBhcmVudBiAgICAgICACgwLEgRVc2VyGICAgICAgMAIDAsSBUZsdWlkGICAgICAgKQLDA', u'name': u'fluid2'}]

# %%
fluid = Fluid.get(fluids[0]["key"])
dir(fluid)
# Out:
# ['Khc',
#  'Kw',
#  'Sw',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'auth',
#  'from_json',
#  'get',
#  'handler',
#  'host',
#  'ls',
#  'rho_hc',
#  'rho_w',
#  'url']

# %%
image_models = ImageModel.ls()
print image_models
# Out:
# [{u'description': u'empty', u'key': u'ag9kZXZ-YWdpbGVtb2RlbHJyWAsSDE1vZGVsclBhcmVudBiAgICAgICACgwLEgRVc2VyGICAgICAgMAIDAsSCkltYWdlTW9kZWwYgICAgICAlAkMCxIKRWFydGhNb2RlbBiAgICAgIDUCww', u'name': u'testing'}]

# %%
im = ImageModel.get(image_models[0]["key"])
dir(im)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_data',
#  'auth',
#  'extents',
#  'from_json',
#  'get',
#  'handler',
#  'host',
#  'image',
#  'ls',
#  'map',
#  'rho',
#  'units',
#  'url',
#  'vp',
#  'vs']
